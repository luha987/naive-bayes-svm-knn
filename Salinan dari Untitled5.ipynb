# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy #if needed!
from numpy import *
import math


# %matplotlib inline
data_base = pd.read_csv("heart_train.csv")
print(data_base)

data_base.drop(["Unnamed: 0"], axis = 1, inplace = True)
data_base

header=data_base.columns
header

list_discrete_no=[]
list_discrete_tag=[]
for i in range(len(header)):
    if (len(np.unique(data_base[header[i]]))<=5):
        #print(header[i])
        list_discrete_tag.append(header[i])
        #print(np.unique(data_base[header[i]]))
        list_discrete_no.append(np.unique(data_base[header[i]]))
list_discrete_tag
data_base_disceret = pd.DataFrame(data_base,columns=list_discrete_tag)
data_base_disceret
list_discrete_no
gp=data_base.groupby(by='target').size()
gp
data_base_0=data_base[data_base['target']==0]
data_base_0
data_base_1=data_base[data_base['target']==1]
data_base_1
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             0   57    1   2       150   168    0        1      174      0
# 1             1   46    1   1       101   197    1        1      156      0
# 2             2   54    0   2       135   304    1        1      170      0
# 3             3   48    1   1       110   229    0        1      168      0
# 4             4   58    0   0       130   197    0        1      131      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 696         696   38    1   2       138   175    0        1      173      0
# 697         697   47    1   2       108   243    0        1      152      0
# 698         698   61    0   0       145   307    0        0      146      1
# 699         699   57    0   0       128   303    0        0      159      0
# 700         700   60    1   0       130   253    0        1      144      1
#
#      oldpeak  slope  ca  thal  target
# 0        1.6      2   0     2       1
# 1        0.0      2   0     3       1
# 2        0.0      2   0     2       1
# 3        1.0      0   0     3       0
# 4        0.6      1   0     2       1
# ..       ...    ...  ..   ...     ...
# 696      0.0      2   4     2       1
# 697      0.0      2   0     2       0
# 698      1.0      1   0     3       0
# 699      0.0      2   1     2       1
# 700      1.4      2   1     3       0
#
# [701 rows x 15 columns]
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     57    1   2       150   168    0        1      174      0      1.6
# 1     46    1   1       101   197    1        1      156      0      0.0
# 2     54    0   2       135   304    1        1      170      0      0.0
# 4     58    0   0       130   197    0        1      131      0      0.6
# 7     34    1   3       118   182    0        0      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 693   38    1   2       138   175    0        1      173      0      0.0
# 694   47    1   2       138   257    0        0      156      0      0.0
# 695   67    0   2       115   564    0        0      160      0      1.6
# 696   38    1   2       138   175    0        1      173      0      0.0
# 699   57    0   0       128   303    0        0      159      0      0.0
#
#      slope  ca  thal  target
# 0        2   0     2       1
# 1        2   0     3       1
# 2        2   0     2       1
# 4        1   0     2       1
# 7        2   0     2       1
# ..     ...  ..   ...     ...
# 693      2   4     2       1
# 694      2   0     2       1
# 695      1   0     3       1
# 696      2   4     2       1
# 699      2   1     2       1
#
# [353 rows x 14 columns]

# %%
data_base.drop(["Unnamed: 0"], axis = 1, inplace = True)
data_base
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     57    1   2       150   168    0        1      174      0      1.6
# 1     46    1   1       101   197    1        1      156      0      0.0
# 2     54    0   2       135   304    1        1      170      0      0.0
# 3     48    1   1       110   229    0        1      168      0      1.0
# 4     58    0   0       130   197    0        1      131      0      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 696   38    1   2       138   175    0        1      173      0      0.0
# 697   47    1   2       108   243    0        1      152      0      0.0
# 698   61    0   0       145   307    0        0      146      1      1.0
# 699   57    0   0       128   303    0        0      159      0      0.0
# 700   60    1   0       130   253    0        1      144      1      1.4
#
#      slope  ca  thal  target
# 0        2   0     2       1
# 1        2   0     3       1
# 2        2   0     2       1
# 3        0   0     3       0
# 4        1   0     2       1
# ..     ...  ..   ...     ...
# 696      2   4     2       1
# 697      2   0     2       0
# 698      1   0     3       0
# 699      2   1     2       1
# 700      2   1     3       0
#
# [701 rows x 14 columns]

# %% [markdown]
# .

# %% [markdown]
# ..

# %% [markdown]
# ...

# %% [markdown]
# **Naive Bayes**

# %%
from sklearn.model_selection import train_test_split
def l2(W):
    lr2=2*W
    return lr2
def sigm(W,x,b):
    si = 1 / ( 1 + np.exp( - (f(W,x) + b ) ) )
    return si
def f(W, x):
    xw=x.dot( W )
    return xw
def dj(W, X, y, lam,m):
    A=sigmoid()
    tmp = ( A - Y.T )
    tmp = np.reshape( tmp, m )
    dW = (np.dot( X.T, tmp ) /m)+(lam*l2(W))
    db = np.sum( tmp ) / m
    W = W - lr * dW
    b = b - lr * db
    return self
def classify(X,W,b):
    Z = 1 / ( 1 + np.exp( - ( X.dot( W ) + b ) ) )
    Y = np.where( Z > 0.5, 1, 0 )
    return Y

# %%
class LR() :
    def __init__( self, lr, iterations,lam ) :
        self.lr = lr
        self.lam=lam
        self.iterations = iterations

    def f(self):
        xw=self.X.dot( self.W )
        return xw

    def l2(self):
        lr2=2*self.W
        return lr2


    def sigm(self):
        si = 1 / ( 1 + np.exp( - ( self.f() + self.b ) ) )
        return si


    def dj( self ) :

        si=self.sigm()
        tmp = ( si - self.Y.T )
        tmp = np.reshape( tmp, self.m )
        dW = (np.dot( self.X.T, tmp ) / self.m)+(self.lam*self.l2())
        db = np.sum( tmp ) / self.m

        self.W = self.W - self.lr * dW
        self.b = self.b - self.lr * db

        return self

    def fit( self, X, Y ) :
        print(X.shape)
        print(Y.shape)
        self.m, self.n = X.shape
        self.W = np.zeros( self.n )
        self.b = 0
        self.X = X
        self.Y = Y

        for i in range( self.iterations ) :
            self.dj()
        return self,self.W



    def classify( self, X ) :
        Z = 1 / ( 1 + np.exp( - ( X.dot( self.W ) + self.b ) ) )
        Y = np.where( Z > 0.5, 1, 0 )
        return Y

# %%
df = pd.read_csv( "heart_train.csv")
df.drop(["Unnamed: 0"], axis = 1, inplace = True)
print(df)
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1:].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0 )
model = LR( lr = 0.001, iterations = 100000,lam=10 )
model.fit( X_train, Y_train )
Y_pred = model.classify( X_test )
Y_test=Y_test.flatten()
Accuracy(Y_test,Y_pred)
model = LR( lr = 0.001, iterations = 100000,lam=1 )
model.fit( X_train, Y_train )
Y_pred = model.classify( X_test )
Y_test=Y_test.flatten()
Accuracy(Y_test,Y_pred)
model = LR( lr = 0.001, iterations = 100000,lam=0.1 )
model.fit( X_train, Y_train )
Y_pred = model.classify( X_test )
Y_test=Y_test.flatten()
Accuracy(Y_test,Y_pred)
model = LR( lr = 0.001, iterations = 100000,lam=0.01 )
model.fit( X_train, Y_train )
Y_pred = model.classify( X_test )
Y_test=Y_test.flatten()
Accuracy(Y_test,Y_pred)
test = pd.read_csv( "heart_test.csv")
test.drop(["Unnamed: 0"], axis = 1, inplace = True)
print(test)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     57    1   2       150   168    0        1      174      0      1.6
# 1     46    1   1       101   197    1        1      156      0      0.0
# 2     54    0   2       135   304    1        1      170      0      0.0
# 3     48    1   1       110   229    0        1      168      0      1.0
# 4     58    0   0       130   197    0        1      131      0      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 696   38    1   2       138   175    0        1      173      0      0.0
# 697   47    1   2       108   243    0        1      152      0      0.0
# 698   61    0   0       145   307    0        0      146      1      1.0
# 699   57    0   0       128   303    0        0      159      0      0.0
# 700   60    1   0       130   253    0        1      144      1      1.4
#
#      slope  ca  thal  target
# 0        2   0     2       1
# 1        2   0     3       1
# 2        2   0     2       1
# 3        0   0     3       0
# 4        1   0     2       1
# ..     ...  ..   ...     ...
# 696      2   4     2       1
# 697      2   0     2       0
# 698      1   0     3       0
# 699      2   1     2       1
# 700      2   1     3       0
#
# [701 rows x 14 columns]
# (560, 13)
# (560, 1)
# (560, 13)
# (560, 1)
# (560, 13)
# (560, 1)
# (560, 13)
# (560, 1)
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     60    1   0       130   253    0        1      144      1      1.4
# 1     67    1   0       160   286    0        0      108      1      1.5
# 2     41    1   2       130   214    0        0      168      0      2.0
# 3     68    1   2       180   274    1        0      150      1      1.6
# 4     64    0   2       140   313    0        1      133      0      0.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 146   65    0   0       150   225    0        0      114      0      1.0
# 147   46    0   1       105   204    0        1      172      0      0.0
# 148   57    1   0       152   274    0        1       88      1      1.2
# 149   55    1   1       130   262    0        1      155      0      0.0
# 150   67    0   0       106   223    0        1      142      0      0.3
#
#      slope  ca  thal  target
# 0        2   1     3       0
# 1        1   3     2       0
# 2        1   0     2       1
# 3        1   0     3       0
# 4        2   0     3       1
# ..     ...  ..   ...     ...
# 146      1   3     3       0
# 147      2   0     2       1
# 148      1   1     3       0
# 149      2   0     2       1
# 150      2   2     2       1
#
# [151 rows x 14 columns]

# %%
X_test = test.iloc[:,:-1].values
Y_test = test.iloc[:,-1:].values
Y_test=Y_test.flatten()
def predict_test_TA(X_train, Y_train,X_test, Y_test,lamda):
    model = LR( lr = 0.001, iterations = 100000,lam=lamda )
    model.fit( X_train, Y_train )
    Y_pred = model.classify(X_test)
    return Accuracy(Y_test,Y_pred)
'Naive Bayes :',predict_test_TA(X_train, Y_train,X_test, Y_test,0.01)
# Out:
# (560, 13)
# (560, 1)
# ('Naive Bayes :', 66.22516556291392)

# %% [markdown]
# ...

# %% [markdown]
# ..

# %% [markdown]
# **SVM** (Support Vector Machine)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
train = pd.read_csv("heart_train.csv")
print(train)
train.drop(["Unnamed: 0"], axis = 1, inplace = True)
train
test = pd.read_csv("heart_test.csv")
print(test)
test.drop(["Unnamed: 0"], axis = 1, inplace = True)
test
X=train.drop('target',axis=1)
Y=train['target']
x_train,x_val,y_train,y_val=train_test_split(X,Y,test_size=0.2,random_state=42)
x_test=test.drop('target',axis=1)
y_test=test['target']
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             0   57    1   2       150   168    0        1      174      0
# 1             1   46    1   1       101   197    1        1      156      0
# 2             2   54    0   2       135   304    1        1      170      0
# 3             3   48    1   1       110   229    0        1      168      0
# 4             4   58    0   0       130   197    0        1      131      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 696         696   38    1   2       138   175    0        1      173      0
# 697         697   47    1   2       108   243    0        1      152      0
# 698         698   61    0   0       145   307    0        0      146      1
# 699         699   57    0   0       128   303    0        0      159      0
# 700         700   60    1   0       130   253    0        1      144      1
#
#      oldpeak  slope  ca  thal  target
# 0        1.6      2   0     2       1
# 1        0.0      2   0     3       1
# 2        0.0      2   0     2       1
# 3        1.0      0   0     3       0
# 4        0.6      1   0     2       1
# ..       ...    ...  ..   ...     ...
# 696      0.0      2   4     2       1
# 697      0.0      2   0     2       0
# 698      1.0      1   0     3       0
# 699      0.0      2   1     2       1
# 700      1.4      2   1     3       0
#
# [701 rows x 15 columns]
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             0   60    1   0       130   253    0        1      144      1
# 1             1   67    1   0       160   286    0        0      108      1
# 2             2   41    1   2       130   214    0        0      168      0
# 3             3   68    1   2       180   274    1        0      150      1
# 4             4   64    0   2       140   313    0        1      133      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 146         146   65    0   0       150   225    0        0      114      0
# 147         147   46    0   1       105   204    0        1      172      0
# 148         148   57    1   0       152   274    0        1       88      1
# 149         149   55    1   1       130   262    0        1      155      0
# 150         150   67    0   0       106   223    0        1      142      0
#
#      oldpeak  slope  ca  thal  target
# 0        1.4      2   1     3       0
# 1        1.5      1   3     2       0
# 2        2.0      1   0     2       1
# 3        1.6      1   0     3       0
# 4        0.2      2   0     3       1
# ..       ...    ...  ..   ...     ...
# 146      1.0      1   3     3       0
# 147      0.0      2   0     2       1
# 148      1.2      1   1     3       0
# 149      0.0      2   0     2       1
# 150      0.3      2   2     2       1
#
# [151 rows x 15 columns]

# %%
def predict_test_TA(x_train,y_train,x_test,y_test,c):
    SVMClassi=SVC(C=c,kernel='linear')
    SVMClassi.fit(x_train,y_train)
    y_pred=SVMClassi.predict(x_test)
    print(Accuracy(y_test,y_pred))
print("SVM :")
predict_test_TA(X,Y,x_test,y_test,0.1)
# Out:
# SVM :
# 80.79470198675497

# %% [markdown]
# ...

# %% [markdown]
# ..

# %% [markdown]
# **KNN** (K-Nearest Neighbor)

# %%
import numpy as np
import pandas as pd
from scipy.stats import mode
import matplotlib.pyplot as plt

# %matplotlib inline
def euclidean(a,b):
    return np.linalg.norm(a-b)
def distance(x,m,X_train,Y_train,k):
    euclidean_distances = np.zeros(m)
    for i in range(m) :
        d = euclidean( x, X_train[i] )
        euclidean_distances[i] = d
    inds = euclidean_distances.argsort()
    Y_train_sorted = Y_train[inds]

    return Y_train_sorted[:K]
def nearest(X_test,k):
    m_test, n = X_test.shape
    Y_nearest = np.zeros( m_test )

    for i in range( m_test) :
        x = X_test[i]
        neighbors = np.zeros(K)
        neighbors = distance(x)
        Y_nearest[i] = knn_decide(neighbors)
    return Y_nearest
def knn_decide(neighbors):
    return mode(neighbors)[0][0]
class KNN() :

    def __init__( self, K ) :
        self.K = K

    def fit( self, X_train, Y_train ) :
        self.X_train = X_train
        self.Y_train = Y_train
        self.m, self.n = X_train.shape

    def distance( self, x ) :
        euclidean_distances = np.zeros( self.m )
        for i in range( self.m ) :
            d = self.euclidean( x, self.X_train[i] )
            euclidean_distances[i] = d
        inds = euclidean_distances.argsort()
        Y_train_sorted = self.Y_train[inds]
        return Y_train_sorted[:self.K]

    def euclidean( self, x, x_train ):

        return np.linalg.norm(x-x_train)

    def knn_decide(self, neighbors):
         return mode( neighbors )[0][0]

    def nearest( self, X_test ) :
        self.X_test = X_test
        self.m_test, self.n = X_test.shape
        Y_nearest = np.zeros( self.m_test )
        for i in range( self.m_test ) :
            x = self.X_test[i]
            neighbors = np.zeros( self.K )
            neighbors = self.distance( x )
            Y_nearest[i] = self.knn_decide(neighbors)

        return Y_nearest
train = pd.read_csv("heart_train.csv")
print(train)
train.drop(["Unnamed: 0"], axis = 1, inplace = True)
train
test = pd.read_csv("heart_test.csv")
print(test)
test.drop(["Unnamed: 0"], axis = 1, inplace = True)
test
# Out:
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             0   57    1   2       150   168    0        1      174      0
# 1             1   46    1   1       101   197    1        1      156      0
# 2             2   54    0   2       135   304    1        1      170      0
# 3             3   48    1   1       110   229    0        1      168      0
# 4             4   58    0   0       130   197    0        1      131      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 696         696   38    1   2       138   175    0        1      173      0
# 697         697   47    1   2       108   243    0        1      152      0
# 698         698   61    0   0       145   307    0        0      146      1
# 699         699   57    0   0       128   303    0        0      159      0
# 700         700   60    1   0       130   253    0        1      144      1
#
#      oldpeak  slope  ca  thal  target
# 0        1.6      2   0     2       1
# 1        0.0      2   0     3       1
# 2        0.0      2   0     2       1
# 3        1.0      0   0     3       0
# 4        0.6      1   0     2       1
# ..       ...    ...  ..   ...     ...
# 696      0.0      2   4     2       1
# 697      0.0      2   0     2       0
# 698      1.0      1   0     3       0
# 699      0.0      2   1     2       1
# 700      1.4      2   1     3       0
#
# [701 rows x 15 columns]
#      Unnamed: 0  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0             0   60    1   0       130   253    0        1      144      1
# 1             1   67    1   0       160   286    0        0      108      1
# 2             2   41    1   2       130   214    0        0      168      0
# 3             3   68    1   2       180   274    1        0      150      1
# 4             4   64    0   2       140   313    0        1      133      0
# ..          ...  ...  ...  ..       ...   ...  ...      ...      ...    ...
# 146         146   65    0   0       150   225    0        0      114      0
# 147         147   46    0   1       105   204    0        1      172      0
# 148         148   57    1   0       152   274    0        1       88      1
# 149         149   55    1   1       130   262    0        1      155      0
# 150         150   67    0   0       106   223    0        1      142      0
#
#      oldpeak  slope  ca  thal  target
# 0        1.4      2   1     3       0
# 1        1.5      1   3     2       0
# 2        2.0      1   0     2       1
# 3        1.6      1   0     3       0
# 4        0.2      2   0     3       1
# ..       ...    ...  ..   ...     ...
# 146      1.0      1   3     3       0
# 147      0.0      2   0     2       1
# 148      1.2      1   1     3       0
# 149      0.0      2   0     2       1
# 150      0.3      2   2     2       1
#
# [151 rows x 15 columns]
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     60    1   0       130   253    0        1      144      1      1.4
# 1     67    1   0       160   286    0        0      108      1      1.5
# 2     41    1   2       130   214    0        0      168      0      2.0
# 3     68    1   2       180   274    1        0      150      1      1.6
# 4     64    0   2       140   313    0        1      133      0      0.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 146   65    0   0       150   225    0        0      114      0      1.0
# 147   46    0   1       105   204    0        1      172      0      0.0
# 148   57    1   0       152   274    0        1       88      1      1.2
# 149   55    1   1       130   262    0        1      155      0      0.0
# 150   67    0   0       106   223    0        1      142      0      0.3
#
#      slope  ca  thal  target
# 0        2   1     3       0
# 1        1   3     2       0
# 2        1   0     2       1
# 3        1   0     3       0
# 4        2   0     3       1
# ..     ...  ..   ...     ...
# 146      1   3     3       0
# 147      2   0     2       1
# 148      1   1     3       0
# 149      2   0     2       1
# 150      2   2     2       1
#
# [151 rows x 14 columns]

# %%
def predict_test_TA(X_train,Y_train,X_test,Y_test,k):
    KnnClassi = KNN(K=k)
    KnnClassi.fit( X_train, Y_train )
    Y_pred = KnnClassi.nearest( X_test)
    Y_test=Y_test.flatten()
    return Accuracy(Y_test,Y_pred)
print("KNN :")
predict_test_TA(X_train,Y_train,X_test,Y_test,1)
# Out:
# KNN :
# 93.37748344370861
